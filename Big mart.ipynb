# %%
import numpy as np
import pandas as pd

# %%
bigmart = pd.read_csv("bigmart.csv")

# %%
bigmart.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
bigmart.shape
# Out:
# (8523, 12)

# %%
from sklearn.model_selection import train_test_split

# %%
bigmart_train, bigmart_test = train_test_split(bigmart, random_state = 1 , test_size = 0.25)

# %%
bigmart_train.shape
# Out:
# (6392, 12)

# %%
bigmart_test.shape
# Out:
# (2131, 12)

# %%
bigmart_test = bigmart_test.drop("Item_Outlet_Sales", axis=1)

# %%
bigmart_test
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1070           NCY05       13.500          Low Fat         0.055102
# 6305           FDM02       12.500          Regular         0.074035
# 8504           NCN18          NaN          Low Fat         0.124111
# 5562           FDM02       12.500          Regular         0.073735
# 1410           FDL21       15.850          Regular         0.007140
# 695            NCV54          NaN          Low Fat         0.032949
# 2909           FDA44       19.700          Low Fat         0.053178
# 3470           FDR48       11.650          Low Fat         0.132248
# 4900           DRA24       19.350          Regular         0.039921
# 5879           NCA42          NaN          Low Fat         0.028410
# 2706           FDU34       18.250          Low Fat         0.075347
# 7277           NCN53        5.175               LF         0.030350
# 3057           FDX25       16.700          Low Fat         0.102036
# ...

# %%
#bigmart_train.to_csv('bigmart_train.csv', sep=',')
bigmart_test.to_csv('bigmart_test.csv', sep=',')
