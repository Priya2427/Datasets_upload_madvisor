# %%
import numpy as np
import pandas as pd

# %%
mobile = pd.read_csv('mobile price classification.csv')

# %%
mobile.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
mobile.shape
# Out:
# (2000, 21)

# %%
from sklearn.model_selection import train_test_split
mobile_train, mobile_test = train_test_split(mobile, random_state = 1 , test_size = 0.25)

# %%
mobile_test = mobile_test.drop("price_range", axis=1)

# %%
mobile_test.head()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 674            1034     0          2.6         1   2       1          45
# 1699           1002     1          1.8         0   1       0          45
# 1282            609     1          0.5         0   4       1          10
# 1315           1510     0          0.6         1   1       0          32
# 1210            805     1          1.7         1   0       1          58
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# 674     0.3        190        3   4        182      1293   969    15     1
# 1699    0.7        180        7   7        948      1007  1234    19    13
# 1282    0.1         81        6   6        113      1524  1905    16     3
# 1315    0.7        135        3   8        963      1520   854     8     2
# 1210    0.9        168        3  10         81      1544  3397     7     6
#
#       talk_time  three_g  touch_screen  wifi
# ...

# %%
mobile_train.to_csv('mobilepriceclass_train.csv', sep=',')
mobile_test.to_csv('mobilepriceclass_test.csv', sep=',')

# %%
mobile_train.shape
# Out:
# (1500, 21)

# %%
mobile_test.shape
# Out:
# (500, 20)
